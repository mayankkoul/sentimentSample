# %% [markdown]
# <a href="https://colab.research.google.com/github/mayankkoul/sentimentSample/blob/main/sampleSentiment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import tweepy

# Twitter API credentials
#consumer_key = ''
#consumer_secret = ''
#access_token = ''
#access_token_secret = ''

# Authenticate to Twitter
#auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
#auth.set_access_token(access_token, access_token_secret)

# Create API object
#api = tweepy.API(auth, wait_on_rate_limit=True)

# Collect tweets
#tweets = []
#for tweet in tweepy.Cursor(api.search_tweets, q="#nyc", lang="en").items(100):
 #   tweets.append(tweet.full_text)

# %%
# prompt: read my data.csv file using pandas

import pandas as pd

df = pd.read_csv('data.csv')

# %%
# prompt: drop the column Unnamed: 0 inplace

df.drop(columns=['Unnamed: 0'], inplace=True)

# %%
df
# Out:
#                id_tweet             tweet_datetime  \
# 0   1189218519398932480  2019-10-29 16:32:44+00:00
# 1   1183029620670713856  2019-10-12 14:40:15+00:00
# 2   1181931198874083333  2019-10-09 13:55:31+00:00
# 3   1180247376117800961  2019-10-04 22:24:37+00:00
# 4   1189203352183361536  2019-10-29 15:32:28+00:00
# 5   1189161368529833988  2019-10-29 12:45:38+00:00
# 6   1189001504553877506  2019-10-29 02:10:23+00:00
# 7   1188998887379525637  2019-10-29 01:59:59+00:00
# 8   1188985304612589570  2019-10-29 01:06:01+00:00
# 9   1188984995668545538  2019-10-29 01:04:47+00:00
# 10  1188984917583187968  2019-10-29 01:04:29+00:00
# 11  1188984866492370946  2019-10-29 01:04:17+00:00
# 12  1188984737651666944  2019-10-29 01:03:46+00:00
# 13  1188945035607363584  2019-10-28 22:26:00+00:00
# 14  1188941823521280013  2019-10-28 22:13:14+00:00
# 15  1188839721184780288  2019-10-28 15:27:31+00:00
# 16  1188815194950119426  2019-10-28 13:50:04+00:00
# 17  1188616384730849281  2019-10-28 00:40:04+00:00
# 18  1188457589086085120  2019-10-27 14:09:04+00:00
# 19  1187776237390958592  2019-10-25 17:01:37+00:00
# 20  1186657393809203203  2019-10-22 14:55:44+00:00
# 21  1185951255539208192  2019-10-20 16:09:47+00:00
# 22  1185755632835670016  2019-10-20 03:12:27+00:00
# 23  1185753262915493890  2019-10-20 03:03:02+00:00
# 24  1185752382749184001  2019-10-20 02:59:32+00:00
# 25  1185686191863205888  2019-10-19 22:36:31+00:00
# 26  1185685742795796480  2019-10-19 22:34:44+00:00
# 27  1185065436586659840  2019-10-18 05:29:52+00:00
# 28  1185021385451552768  2019-10-18 02:34:49+00:00
# 29  1184915402041839616  2019-10-17 19:33:41+00:00
# 30  1184534538770403330  2019-10-16 18:20:16+00:00
# 31  1184510013844480000  2019-10-16 16:42:49+00:00
# 32  1184472924113326080  2019-10-16 14:15:26+00:00
# 33  1184472329436454912  2019-10-16 14:13:04+00:00
# 34  1183938304410079233  2019-10-15 02:51:02+00:00
# 35  1183869998026113025  2019-10-14 22:19:37+00:00
# 36  1183804588115275776  2019-10-14 17:59:42+00:00
# 37  1183569543437770752  2019-10-14 02:25:43+00:00
# 38  1183457520611987456  2019-10-13 19:00:35+00:00
# 39  1183409154045681667  2019-10-13 15:48:23+00:00
# 40  1183409046948319235  2019-10-13 15:47:58+00:00
# 41  1183408992053350401  2019-10-13 15:47:45+00:00
# 42  1183383929618874369  2019-10-13 14:08:09+00:00
# 43  1183358499931262976  2019-10-13 12:27:06+00:00
# 44  1182425181605765120  2019-10-10 22:38:26+00:00
# 45  1182253397493329921  2019-10-10 11:15:49+00:00
# 46  1182101744391770112  2019-10-10 01:13:12+00:00
# 47  1181566902520418304  2019-10-08 13:47:56+00:00
# 48  1181524140039254016  2019-10-08 10:58:01+00:00
# 49  1181270939583029259  2019-10-07 18:11:53+00:00
# 50  1180982723948797952  2019-10-06 23:06:37+00:00
# 51  1180597507887230976  2019-10-05 21:35:54+00:00
# 52  1180594751772299264  2019-10-05 21:24:57+00:00
# 53  1180558701817663489  2019-10-05 19:01:42+00:00
# 54  1180247376117800961  2019-10-04 22:24:37+00:00
# 55  1180179442636861440  2019-10-04 17:54:40+00:00
# 56  1180060775613894657  2019-10-04 10:03:08+00:00
#
#                                         tweet_content  \
# 0   @I_LOVE_NY should do something about the @Dist...
# 1   @RiversideParkNY beginning to show some color ...
# 2   Part 3 of @718_cyclery #microtour 7 to Harrima...
# 3                                                 Lol
# 4   Governor Cuomo @NYGovCuomo and Delta CEO Ed Ba...
# 5   Cloudy ,rainy & and temperature in the 50s mis...
# 6   I always answer that question with: Because ev...
# 7   I couldn’t agree more. I call it the magical s...
# 8   That makes me happy Fro that you’ve been here ...
# 9                     It truly is an amazing place! 😃
# 10                                             Yep! 😃
# 11                     It sure is! No place like it 😃
# 12  Love it here! Hope San Fran is good to you as ...
# 13  Thanks for featuring my photograph @NYCParks #...
# 14  Thank you. Actually I moved to NYC 7 years ago...
# 15  Who is ready for the @nyrr @nycmarathon this c...
# 16  #photography #photooftheday #infinity_newyork ...
# 17                           Sony A7r3 and thank you!
# 18      Landing in New York. #NYC @nycgo #newyorkcity
# 19  Just got to @nycgo and I’m already thinking ab...
# 20  Experience, #luxury #comfort #elegance &amp; #...
# 21                                               Woah
# 22          Thanks for the prompt response and action
# 23      Yes that’s happening now car #1778 on 6 train
# 24  Now on 6 train people are standing for others ...
# 25  The beautiful interior of St Patrick’s Cathedr...
# 26  Views from @BklynNavyYard @brklynbes @ThePhoto...
# 27                                         Beautiful!
# 28                                  Thank you so much
# 29  What a place 😳🤯 #hellohudsonyards #hudsonyards...
# 30  Ahhh. Thanks. And loved your new #initiatives ...
# 31                                   Thank you Vera 😊
# 32  Autumn colors in upstate New York. @nycfeeling...
# 33  #China is largest international market for @ny...
# 34  NYC revives ‘Famous Original New York City’ cr...
# 35  1. Wide Camera 2. Ultra Wide Camera 3. Telepho...
# 36  Looking forward to hosting this funny 😆 bunch ...
# 37  #newyorkcity trip #2019 . . . nycityworld @yan...
# 38  #NYC 🗽 . . . . . . #newyorkcity #newyork #usa ...
# 39  Thank you! Thats the Jefferson Market Library....
# 40                          It’s a beautiful building
# 41                                          Thank you
# 42  A weekend in #NYC means a weekend of gastronom...
# 43  And #Iceskating season has begun. The #Rockefe...
# 44  A house in #Clifton, #Staten_lsland. #statenis...
# 45  Who knows what train station I'm at? #naturelo...
# 46  @GraceChurchNYC #seeyourcity #NewYork #thisisn...
# 47                                     No no no no no
# 48  Un hôtel de caractère,niché, à @nycgo,dans l’a...
# 49  @n8s_paints #CUEart #NatessaAmin #AliBanisadr ...
# 50                                     Magical photo.
# 51                Yes the pixel 3xl. Love this phone.
# 52                                         So true!!!
# 53  Toured the National Lighthouse Museum today. A...
# 54                                                Lol
# 55  How do you commute? #newyorkcity #helicopter #...
# 56  @nycgo recèle de merveilles touristiques,encor...
#
#                                        tweet_mentions  tweet_retweets
# 0                           @I_LOVE_NY @DistriktHotel               0
# 1                         @RiversideParkNY @I_LOVE_NY               0
# 2                             @718_Cyclery @I_LOVE_NY               0
# 3                                                 NaN               0
# 4   @NYGovCuomo @Delta @LGAairport @nycgo @nycgo_p...               1
# 5   @NYCParks @NY1weather @WeatherNation @nycgo @s...               0
# 6                                                 NaN               0
# 7                                                 NaN               0
# 8                                                 NaN               0
# 9                                                 NaN               0
# 10                                                NaN               0
# 11                                                NaN               0
# 12                                                NaN               0
# 13  @NYCParks @GrnVillageNYC @TimeOutNewYork @NY1 ...               0
# 14                                                NaN               0
# 15  @nyrr @nycmarathon @nycfeelings @NYC @NYCParks...               0
# 16  @nycgo @TimeOutNewYork @nycfeelings @NYCDailyP...               0
# 17                                                NaN               0
# 18                                             @nycgo               1
# 19                                             @nycgo               0
# 20  @Mohans_Tailors @GQMagazine @WSJ @nycgo @esqui...               0
# 21                                                NaN               0
# 22                                                NaN               0
# 23                                                NaN               0
# 24  @BilldeBlasio @nytaxpayerparty @nycgo @cnnbrk ...              24
# 25                                             @nycgo               0
# 26  @BklynNavyYard @brklynbes @ThePhotoHour @nycgo...               2
# 27                                                NaN               0
# 28                                                NaN               0
# 29                                             @nycgo               0
# 30                                                NaN               0
# 31                                                NaN               0
# 32  @nycfeelings @nycgo @NYCDailyPics @NYCONLY @Al...               1
# 33     @nycgo @SMS_summit @Taisa_Veras @getsocialjack               2
# 34                       @TheDrum @nycgo_press @nycgo               2
# 35  @Apple @NycPrimeShot @nycgo @nycfeelings @gant...               5
# 36  @EmpireOutlets @amitandon @smanak @listen2arun...               2
# 37               @Yankees @monicadrake @nycgo @nycfat               0
# 38                                 @nycgo @spoilednyc               0
# 39                                                NaN               0
# 40                                                NaN               0
# 41                                                NaN               0
# 42    @AuCheval @little_spain @StarrRestaurant @nycgo               0
# 43  @nycgo @TimeOutNewYork @ThePhotoHour @nycfeelings              27
# 44                                             @nycgo               0
# 45                     @MTA @NYCTSubway @nycgo @nycgo               0
# 46  @GraceChurchNYC @nycgo @TimeOutNewYork @nycfee...               0
# 47                                                NaN               0
# 48                            @nycgo @TheRoxyHotelNYC               1
# 49  @n8s_paints @nycgo @NYCMediaMix @soho_press @n...               0
# 50                                                NaN               0
# 51                                                NaN               0
# 52                                                NaN               0
# 53  @USCG @uscoastguard @HISTORY @StatenI @StatenI...               0
# 54                                                NaN               0
# 55  @NYCDailyPics @NYC @NYCONLY @ABC7NY @nycgov @n...               0
# 56                                             @nycgo               0

# %%
# prompt: Using dataframe df: make a plot of number of tweets per day you can use tweet_id for counting

import pandas as pd
import matplotlib.pyplot as plt

# Convert tweet_datetime to datetime object
df['tweet_datetime'] = pd.to_datetime(df['tweet_datetime'])

# Group by date and count the number of tweets
df_grouped = df.groupby(df['tweet_datetime'].dt.date)['id_tweet'].count()

# Plot the number of tweets per day
df_grouped.plot(kind='line')
plt.xlabel('Date')
plt.ylabel('Number of Tweets')
plt.title('Number of Tweets per Day')
plt.show()

# %%
import nltk
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
import pandas as pd
from nltk.stem import PorterStemmer, WordNetLemmatizer
from nltk.tokenize import word_tokenize


# Initialize the stemmer and lemmatizer
stemmer = PorterStemmer()
lemmatizer = WordNetLemmatizer()

# Function to apply stemming and lemmatization to text
def preprocess_text(text):
    # Tokenize text
    tokens = word_tokenize(text)

    # Apply stemming and lemmatization
    stemmed_tokens = [stemmer.stem(token) for token in tokens]
    lemmatized_tokens = [lemmatizer.lemmatize(token) for token in tokens]

    # Join tokens back to string
    return " ".join(text), " ".join(stemmed_tokens), " ".join(lemmatized_tokens)


# Apply preprocessing to each tweet in the DataFrame
df['processed_data'] = df['tweet_content'].apply(lambda x: preprocess_text(x))

# %%
# Example: Analyzing sentiment of lemmatized text
from textblob import TextBlob

# Assuming the DataFrame column 'processed_data' has tuples (original, stemmed, lemmatized)
tweets_with_sentiment = []

for row in df.itertuples(index=False):
    original, stemmed, lemmatized = row.processed_data  # Adjust based on actual column name
    analysis = TextBlob(lemmatized)
    tweets_with_sentiment.append((original, stemmed,lemmatized, analysis.sentiment.polarity, analysis.sentiment.subjectivity))

# Optionally, you can store the results back into a DataFrame
tweets_sentiment_df = pd.DataFrame(tweets_with_sentiment, columns=["Original", "Stemmed","Lemmatized", "Polarity", "Subjectivity"])

# %%
tweets_sentiment_df
# Out:
#                                              Original  \
# 0   @ I _ L O V E _ N Y   s h o u l d   d o   s o ...
# 1   @ R i v e r s i d e P a r k N Y   b e g i n n ...
# 2   P a r t   3   o f   @ 7 1 8 _ c y c l e r y   ...
# 3                                               L o l
# 4   G o v e r n o r   C u o m o   @ N Y G o v C u ...
# 5   C l o u d y   , r a i n y   &   a n d   t e m ...
# 6   I   a l w a y s   a n s w e r   t h a t   q u ...
# 7   I   c o u l d n ’ t   a g r e e   m o r e .   ...
# 8   T h a t   m a k e s   m e   h a p p y   F r o ...
# 9   I t   t r u l y   i s   a n   a m a z i n g   ...
# 10                                        Y e p !   😃
# 11  I t   s u r e   i s !   N o   p l a c e   l i ...
# 12  L o v e   i t   h e r e !   H o p e   S a n   ...
# 13  T h a n k s   f o r   f e a t u r i n g   m y ...
# 14  T h a n k   y o u .   A c t u a l l y   I   m ...
# 15  W h o   i s   r e a d y   f o r   t h e   @ n ...
# 16  # p h o t o g r a p h y   # p h o t o o f t h ...
# 17    S o n y   A 7 r 3   a n d   t h a n k   y o u !
# 18  L a n d i n g   i n   N e w   Y o r k .   # N ...
# 19  J u s t   g o t   t o   @ n y c g o   a n d   ...
# 20  E x p e r i e n c e ,   # l u x u r y   # c o ...
# 21                                            W o a h
# 22  T h a n k s   f o r   t h e   p r o m p t   r ...
# 23  Y e s   t h a t ’ s   h a p p e n i n g   n o ...
# 24  N o w   o n   6   t r a i n   p e o p l e   a ...
# 25  T h e   b e a u t i f u l   i n t e r i o r   ...
# 26  V i e w s   f r o m   @ B k l y n N a v y Y a ...
# 27                                B e a u t i f u l !
# 28                  T h a n k   y o u   s o   m u c h
# 29  W h a t   a   p l a c e   😳 🤯   # h e l l o h ...
# 30  A h h h .   T h a n k s .   A n d   l o v e d ...
# 31                    T h a n k   y o u   V e r a   😊
# 32  A u t u m n   c o l o r s   i n   u p s t a t ...
# 33  # C h i n a   i s   l a r g e s t   i n t e r ...
# 34  N Y C   r e v i v e s   ‘ F a m o u s   O r i ...
# 35  1 .   W i d e   C a m e r a   2 .   U l t r a ...
# 36  L o o k i n g   f o r w a r d   t o   h o s t ...
# 37  # n e w y o r k c i t y   t r i p   # 2 0 1 9 ...
# 38  # N Y C   🗽   .   .   .   .   .   .   # n e w ...
# 39  T h a n k   y o u !   T h a t s   t h e   J e ...
# 40  I t ’ s   a   b e a u t i f u l   b u i l d i n g
# 41                                  T h a n k   y o u
# 42  A   w e e k e n d   i n   # N Y C   m e a n s ...
# 43  A n d   # I c e s k a t i n g   s e a s o n   ...
# 44  A   h o u s e   i n   # C l i f t o n ,   # S ...
# 45  W h o   k n o w s   w h a t   t r a i n   s t ...
# 46  @ G r a c e C h u r c h N Y C   # s e e y o u ...
# 47                        N o   n o   n o   n o   n o
# 48  U n   h ô t e l   d e   c a r a c t è r e , n ...
# 49  @ n 8 s _ p a i n t s   # C U E a r t   # N a ...
# 50                        M a g i c a l   p h o t o .
# 51  Y e s   t h e   p i x e l   3 x l .   L o v e ...
# 52                                S o   t r u e ! ! !
# 53  T o u r e d   t h e   N a t i o n a l   L i g ...
# 54                                              L o l
# 55  H o w   d o   y o u   c o m m u t e ?   # n e ...
# 56  @ n y c g o   r e c è l e   d e   m e r v e i ...
#
#                                               Stemmed  \
# 0   @ i_love_ni should do someth about the @ distr...
# 1   @ riversideparkni begin to show some color on ...
# 2   part 3 of @ 718_cycleri # microtour 7 to harri...
# 3                                                 lol
# 4   governor cuomo @ nygovcuomo and delta ceo ed b...
# 5   cloudi , raini & and temperatur in the 50 miss...
# 6   i alway answer that question with : becaus eve...
# 7   i couldn ’ t agre more . i call it the magic s...
# 8   that make me happi fro that you ’ ve been here...
# 9                       it truli is an amaz place ! 😃
# 10                                            yep ! 😃
# 11                    it sure is ! no place like it 😃
# 12  love it here ! hope san fran is good to you as...
# 13  thank for featur my photograph @ nycpark # fat...
# 14  thank you . actual i move to nyc 7 year ago fr...
# 15  who is readi for the @ nyrr @ nycmarathon thi ...
# 16  # photographi # photooftheday # infinity_newyo...
# 17                          soni a7r3 and thank you !
# 18        land in new york . # nyc @ nycgo # newyorkc
# 19  just got to @ nycgo and i ’ m alreadi think ab...
# 20  experi , # luxuri # comfort # eleg & amp ; # s...
# 21                                               woah
# 22            thank for the prompt respons and action
# 23       ye that ’ s happen now car # 1778 on 6 train
# 24  now on 6 train peopl are stand for other to sl...
# 25  the beauti interior of st patrick ’ s cathedr ...
# 26  view from @ bklynnavyyard @ brklynb @ thephoto...
# 27                                           beauti !
# 28                                  thank you so much
# 29  what a place 😳🤯 # hellohudsonyard # hudsonyard...
# 30  ahhh . thank . and love your new # initi , and...
# 31                                   thank you vera 😊
# 32  autumn color in upstat new york . @ nycfeel @ ...
# 33  # china is largest intern market for @ nycgo ,...
# 34  nyc reviv ‘ famou origin new york citi ’ creat...
# 35  1 . wide camera 2 . ultra wide camera 3 . tele...
# 36  look forward to host thi funni 😆 bunch @ empir...
# 37  # newyorkc trip # 2019 . . . nycityworld @ yan...
# 38  # nyc 🗽 . . . . . . # newyorkc # newyork # usa...
# 39  thank you ! that the jefferson market librari ...
# 40                              it ’ s a beauti build
# 41                                          thank you
# 42  a weekend in # nyc mean a weekend of gastronom...
# 43  and # icesk season ha begun . the # rockefelle...
# 44  a hous in # clifton , # staten_lsland . # stat...
# 45  who know what train station i 'm at ? # nature...
# 46  @ gracechurchnyc # seeyourc # newyork # thisis...
# 47                                     no no no no no
# 48  un hôtel de caractèr , niché , à @ nycgo , dan...
# 49  @ n8s_paint # cueart # natessaamin # alibanisa...
# 50                                      magic photo .
# 51                ye the pixel 3xl . love thi phone .
# 52                                      so true ! ! !
# 53  tour the nation lighthous museum today . amaz ...
# 54                                                lol
# 55  how do you commut ? # newyorkc # helicopt # ne...
# 56  @ nycgo recèl de merveil touristiqu , encor co...
#
#                                            Lemmatized  Polarity  Subjectivity
# 0   @ I_LOVE_NY should do something about the @ Di... -0.222222      0.222222
# 1   @ RiversideParkNY beginning to show some color...  0.000000      0.000000
# 2   Part 3 of @ 718_cyclery # microtour 7 to Harri... -0.433333      0.600000
# 3                                                 Lol  0.800000      0.700000
# 4   Governor Cuomo @ NYGovCuomo and Delta CEO Ed B...  0.157576      0.436364
# 5   Cloudy , rainy & and temperature in the 50 mis...  0.150000      0.275000
# 6   I always answer that question with : Because e...  0.600000      1.000000
# 7   I couldn ’ t agree more . I call it the magica...  0.500000      0.750000
# 8   That make me happy Fro that you ’ ve been here...  0.825000      1.000000
# 9                    It truly is an amazing place ! 😃  0.750000      0.900000
# 10                                            Yep ! 😃  0.000000      0.000000
# 11                    It sure is ! No place like it 😃  0.625000      0.888889
# 12  Love it here ! Hope San Fran is good to you a ...  0.708333      0.650000
# 13  Thanks for featuring my photograph @ NYCParks ...  0.200000      0.200000
# 14  Thank you . Actually I moved to NYC 7 year ago...  0.083333      0.227778
# 15  Who is ready for the @ nyrr @ nycmarathon this...  0.100000      0.375000
# 16  # photography # photooftheday # infinity_newyo...  0.000000      0.000000
# 17                          Sony A7r3 and thank you !  0.000000      0.000000
# 18  Landing in New York . # NYC @ nycgo # newyorkcity  0.136364      0.454545
# 19  Just got to @ nycgo and I ’ m already thinking...  0.100000      0.400000
# 20  Experience , # luxury # comfort # elegance & a...  0.437500      0.650000
# 21                                               Woah  0.000000      0.000000
# 22          Thanks for the prompt response and action  0.150000      0.150000
# 23   Yes that ’ s happening now car # 1778 on 6 train  0.000000      0.000000
# 24  Now on 6 train people are standing for others ...  0.000000      0.000000
# 25  The beautiful interior of St Patrick ’ s Cathe...  0.850000      1.000000
# 26  Views from @ BklynNavyYard @ brklynbes @ ThePh...  0.000000      0.000000
# 27                                        Beautiful !  1.000000      1.000000
# 28                                  Thank you so much  0.200000      0.200000
# 29  What a place 😳🤯 # hellohudsonyards # hudsonyar...  0.000000      0.000000
# 30  Ahhh . Thanks . And loved your new # initiativ...  0.321591      0.413636
# 31                                   Thank you Vera 😊  0.000000      0.000000
# 32  Autumn color in upstate New York . @ nycfeelin...  0.136364      0.454545
# 33  # China is largest international market for @ ...  0.112121      0.218182
# 34  NYC revives ‘ Famous Original New York City ’ ...  0.377841      0.801136
# 35  1 . Wide Camera 2 . Ultra Wide Camera 3 . Tele... -0.100000      0.400000
# 36  Looking forward to hosting this funny 😆 bunch ...  0.730208      0.883333
# 37  # newyorkcity trip # 2019 . . . nycityworld @ ...  0.000000      0.000000
# 38  # NYC 🗽 . . . . . . # newyorkcity # newyork # ...  0.000000      0.000000
# 39  Thank you ! Thats the Jefferson Market Library...  0.068182      0.260606
# 40                        It ’ s a beautiful building  0.850000      1.000000
# 41                                          Thank you  0.000000      0.000000
# 42  A weekend in # NYC mean a weekend of gastronom...  0.097500      0.457500
# 43  And # Iceskating season ha begun . The # Rocke... -0.100000      0.100000
# 44  A house in # Clifton , # Staten_lsland . # sta...  0.000000      0.000000
# 45  Who know what train station I 'm at ? # nature...  0.000000      0.000000
# 46  @ GraceChurchNYC # seeyourcity # NewYork # thi...  0.000000      0.000000
# 47                                     No no no no no  0.000000      0.000000
# 48  Un hôtel de caractère , niché , à @ nycgo , da...  0.000000      0.000000
# 49  @ n8s_paints # CUEart # NatessaAmin # AliBanis...  0.000000      0.000000
# 50                                    Magical photo .  0.500000      1.000000
# 51              Yes the pixel 3xl . Love this phone .  0.500000      0.600000
# 52                                      So true ! ! !  0.683594      0.650000
# 53  Toured the National Lighthouse Museum today . ...  0.575000      0.775000
# 54                                                Lol  0.800000      0.700000
# 55  How do you commute ? # newyorkcity # helicopte...  0.000000      0.000000
# 56  @ nycgo recèle de merveilles touristiques , en...  0.000000      0.000000

# %%
# @title Polarity vs Subjectivity

from matplotlib import pyplot as plt
tweets_sentiment_df.plot(kind='scatter', x='Polarity', y='Subjectivity', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# prompt: create a word cloud using the tweets sentiment df using Original column

import matplotlib.pyplot as plt
from wordcloud import WordCloud

# Create a word cloud using the original text from the tweets
text = " ".join(df["tweet_content"].tolist())

wordcloud = WordCloud(width=800, height=600, background_color="white").generate(text)

# Display the word cloud
plt.figure(figsize=(10, 7))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
# prompt: a donut chart to show share of polarity from tweets_sentiment_df, to show how much percentage of tweets are positive, vs neutral vs  negative

import matplotlib.pyplot as plt
# Calculate the percentage of positive, neutral, and negative tweets
positive_tweets = tweets_sentiment_df[tweets_sentiment_df['Polarity'] > 0].shape[0]
neutral_tweets = tweets_sentiment_df[tweets_sentiment_df['Polarity'] == 0].shape[0]
negative_tweets = tweets_sentiment_df[tweets_sentiment_df['Polarity'] < 0].shape[0]

total_tweets = positive_tweets + neutral_tweets + negative_tweets

positive_percentage = positive_tweets / total_tweets * 100
neutral_percentage = neutral_tweets / total_tweets * 100
negative_percentage = negative_tweets / total_tweets * 100

# Create a donut chart
labels = ['Positive', 'Neutral', 'Negative']
sizes = [positive_percentage, neutral_percentage, negative_percentage]
colors = ['green', 'yellow', 'red']

fig, ax = plt.subplots()
ax.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90, colors=colors)
ax.axis('equal')  # Equal aspect ratio ensures a circular pie chart

# Add a title and show the chart
ax.set_title('Share of Polarity from Tweets')
plt.show()

# %%
# prompt: a donut chart to show share of subjectivity from tweets_sentiment_df, to show how much percentage of tweets are opinion, vs neutral vs  fact

import matplotlib.pyplot as plt
# Calculate the percentage of subjective, neutral, and objective tweets
subjective_tweets = tweets_sentiment_df[tweets_sentiment_df['Subjectivity'] > 0.5].shape[0]
neutral_tweets = tweets_sentiment_df[tweets_sentiment_df['Subjectivity'] == 0.5].shape[0]
objective_tweets = tweets_sentiment_df[tweets_sentiment_df['Subjectivity'] < 0.5].shape[0]

total_tweets = subjective_tweets + neutral_tweets + objective_tweets

subjective_percentage = subjective_tweets / total_tweets * 100
neutral_percentage = neutral_tweets / total_tweets * 100
objective_percentage = objective_tweets / total_tweets * 100

# Create a donut chart
labels = ['Subjective', 'Neutral', 'Objective']
sizes = [subjective_percentage, neutral_percentage, objective_percentage]
colors = ['green', 'yellow', 'red']

fig, ax = plt.subplots()
ax.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90, colors=colors)
ax.axis('equal')  # Equal aspect ratio ensures a circular pie chart

# Add a title and show the chart
ax.set_title('Share of Subjectivity from Tweets')
plt.show()
